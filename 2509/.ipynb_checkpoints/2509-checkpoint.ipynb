# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# Экспортируем тестовые данные и задаем названия колонкам

# %%
data = pd.read_csv('seeds_dataset.txt', sep="	", names=["area A", "perimeter P", "compactness C = 4*pi*A/P^2", "length of kernel", "width of kernel", "asymmetry coefficient", "length of kernel groove","cultivar"])
data.head()
# Out:
#    area A  perimeter P  compactness C = 4*pi*A/P^2  length of kernel  \
# 0   15.26        14.84                      0.8710             5.763
# 1   14.88        14.57                      0.8811             5.554
# 2   14.29        14.09                      0.9050             5.291
# 3   13.84        13.94                      0.8955             5.324
# 4   16.14        14.99                      0.9034             5.658
#
#    width of kernel  asymmetry coefficient  length of kernel groove  cultivar
# 0            3.312                  2.221                    5.220         1
# 1            3.333                  1.018                    4.956         1
# 2            3.337                  2.699                    4.825         1
# 3            3.379                  2.259                    4.805         1
# 4            3.562                  1.355                    5.175         1

# %% [markdown]
# Описываем данные

# %%
data.describe()
data.shape
# Out:
# (210, 8)

# %%
data.corr()
from pandas.plotting import scatter_matrix
scatter_matrix(data, alpha = .05, figsize = (10, 10))
pass

# %% [markdown]
# т.к. NAN значения и категориальные признаки отсутствуют, преобразования не нужны

# %%
print(data.isnull().values.sum()) # number of NaN-values in the dataset
len([c for c in data.columns if data[c].dtype.name == 'object']) # categorical_columns
len([c for c in data.columns if data[c].dtype.name != 'object']) # numerical_columns
# Out:
# 0
# 8

# %% [markdown]
# Отделяем столбец, значение которого будем предсказывать, остальные данные нормируем, т.к. того требует knn

# %%
x = data.drop(('cultivar'), axis = 1) 
y = data['cultivar']
x = (x - x.mean(axis = 0))/x.std(axis = 0)
x.describe()
# Out:
#              area A   perimeter P  compactness C = 4*pi*A/P^2  \
# count  2.100000e+02  2.100000e+02                2.100000e+02
# mean  -2.254281e-15 -2.566730e-15                1.402780e-15
# std    1.000000e+00  1.000000e+00                1.000000e+00
# min   -1.463218e+00 -1.645753e+00               -2.661876e+00
# 25%   -8.858385e-01 -8.494033e-01               -5.966534e-01
# 50%   -1.692697e-01 -1.832261e-01                1.037448e-01
# 75%    8.445808e-01  8.849547e-01                7.099807e-01
# max    2.176333e+00  2.060336e+00                2.001803e+00
#
#        length of kernel  width of kernel  asymmetry coefficient  \
# count      2.100000e+02     2.100000e+02           2.100000e+02
# mean      -4.132144e-15    -2.622241e-16           3.827626e-16
# std        1.000000e+00     1.000000e+00           1.000000e+00
# min       -1.646566e+00    -1.664233e+00          -1.952105e+00
# 25%       -8.267062e-01    -8.329169e-01          -7.573380e-01
# 50%       -2.370616e-01    -5.719866e-02          -6.730769e-02
# 75%        7.927006e-01     8.025778e-01           7.106807e-01
# max        2.361889e+00     2.050213e+00           3.163032e+00
#
#        length of kernel groove
# count             2.100000e+02
# mean             -1.691768e-16
# std               1.000000e+00
# min              -1.808966e+00
# 25%              -7.387301e-01
# 50%              -3.765590e-01
# 75%               9.541143e-01
# max               2.323446e+00

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 1) # выделяем 33 процента в тестовую выборку
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 10) #Обучаем алгоритм для десяти соседей и с Евклидовым расстоянием 
knn.fit(x_train, y_train)
y_train_predict = knn.predict(x_train)
y_test_predict = knn.predict(x_test)

err_train = np.mean(y_train != y_train_predict)
err_test  = np.mean(y_test  != y_test_predict)

print(err_train, err_test)
# Out:
# 0.0884353741497 0.047619047619

# %% [markdown]
# Подбираем оптимальное число соседей

# %%
from sklearn.model_selection import GridSearchCV
nnb = [1, 3, 5, 10, 15, 20, 25, 35, 45, 55]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10)
grid.fit(x_train, y_train)

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print(best_cv_err, best_n_neighbors)
# Out:
# 0.0680272108844 1

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(x_train, y_train)

err_train = np.mean(y_train != knn.predict(x_train))
err_test  = np.mean(y_test  != knn.predict(x_test))

print(err_train, err_test)
# Out:
# 0.0 0.0952380952381

# %% [markdown]
# Построим график зависимости точности алгоритма от количества соседей

# %%
import matplotlib.pyplot as plt
errs_train, errs_test = [],[]
for k in range(1,148):
    knn = KNeighborsClassifier(n_neighbors = k).fit(x_train, y_train)
    errs_train.append(np.mean(knn.predict(x_train)!=y_train))
    errs_test.append(np.mean(knn.predict(x_test)!=y_test))

# %matplotlib inline
plt.plot(range(1,148), errs_train, '.-r', label = 'Train error')
plt.plot(range(1,148), errs_test,  '.-b', label = 'Test error')    
plt.legend(loc = 2)
pass

# %%
# %matplotlib inline
plt.plot(range(1,10), errs_train[:9], '.-r', label = 'Train error')
plt.plot(range(1,10), errs_test[:9],  '.-b', label = 'Test error')    
plt.legend(loc = 'best')
pass

# %%
from sklearn.model_selection import cross_val_score
model = KNeighborsClassifier(n_neighbors = 1)
CV_scores = cross_val_score(model, x, y, cv = 10)
print(CV_scores)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
print("Error:    %0.2f (+/- %0.2f)" % (1 - scores.mean(), scores.std() * 2))
# Out:
# [ 1.          1.          0.95238095  1.          0.95238095  0.9047619
#   0.85714286  0.95238095  0.80952381  0.66666667]
# Accuracy: 0.71 (+/- 0.27)
# Error:    0.29 (+/- 0.27)

# %%
CV_errs = []
for k in range(1,148):
    model = KNeighborsClassifier(n_neighbors = k)
    scores = cross_val_score(model, x, y, cv = 10)
    CV_errs.append(1 - scores.mean())

plt.plot(range(1,148), err_cv, '.-m', label = 'CV error')
plt.legend(loc = 'best')

# %% [markdown]
# # Линейный дискриминантный анализ (LBA)

# %%
from sklearn import discriminant_analysis
lda_model = discriminant_analysis.LinearDiscriminantAnalysis()
lda_model.fit(x_train, y_train)
# Out:
# LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#               solver='svd', store_covariance=False, tol=0.0001)

# %%
err_train = np.mean(y_train != lda_model.predict(x_train))
err_test = np.mean(y_test != lda_model.predict(x_test))
print(err_train, err_test)
# Out:
# 0.0408163265306 0.0

# %% [markdown]
# # Квадратичный дискриминантный анализ (QDA)

# %%
qda = discriminant_analysis.QuadraticDiscriminantAnalysis()
qda.fit(x_train, y_train)
# Out:
# QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                store_covariance=False, store_covariances=None, tol=0.0001)

# %%
err_train = np.mean(y_train != qda.predict(x_train))
err_test = np.mean(y_test != qda.predict(x_test))
print(err_train, err_test)
# Out:
# 0.0408163265306 0.031746031746

# %% [markdown]
# # Логистическая регрессия

# %%
from sklearn.linear_model import LogisticRegression
logistic_model = LogisticRegression()
logistic_model.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
err_train = np.mean(y_train != logistic_model.predict(x_train))
err_test = np.mean(y_test != logistic_model.predict(x_test))
print(err_train, err_test)
# Out:
# 0.0680272108844 0.047619047619

# %% [markdown]
# # Машина опорных векторов (SVM)

# %%
from sklearn.svm import SVC # "Support Vector Classifier"
svc_model = SVC(kernel = 'linear')
svc_model.fit(x_train, y_train)
err_train = np.mean(y_train != svc_model.predict(x_train))
err_test = np.mean(y_test != svc_model.predict(x_test))
print(err_train, err_test)
# Out:
# 0.0544217687075 0.0634920634921

# %%
svc_model = SVC(kernel = 'rbf')
svc_model.fit(x_train, y_train)
err_train = np.mean(y_train != svc_model.predict(x_train))
err_test = np.mean(y_test != svc_model.predict(x_test))
print(err_train, err_test)
# Out:
# 0.0612244897959 0.047619047619

# %%
svc_model = SVC(kernel = 'poly')
svc_model.fit(x_train, y_train)
err_train = np.mean(y_train != svc_model.predict(x_train))
err_test = np.mean(y_test != svc_model.predict(x_test))
print(err_train, err_test)
# Out:
# 0.12925170068 0.031746031746

# %%
svc_model = SVC(kernel = 'sigmoid')
svc_model.fit(x_train, y_train)
err_train = np.mean(y_train != svc_model.predict(x_train))
err_test = np.mean(y_test != svc_model.predict(x_test))
print(err_train, err_test)
# Out:
# 0.0952380952381 0.0634920634921

# %%
from sklearn.naive_bayes import GaussianNB
gnb_model = GaussianNB()
gnb_model.fit(x_train, y_train)
# Out:
# GaussianNB(priors=None)

# %%
err_train = np.mean(y_train != gnb_model.predict(x_train))
err_test = np.mean(y_test != gnb_model.predict(x_test))
print(err_train, err_test)
# Out:
# 0.0952380952381 0.0793650793651
